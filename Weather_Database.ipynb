# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy as hen

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = hen.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficent count.
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
base_url = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval         ")
print("---------------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into the city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                          "Weather Description": city_description,
                         "Date": city_date})
        
    # If an error is experience, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------------------")
print("Data Retrieval Complete            ")
print("-----------------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | quime
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | palauig
# Processing Record 5 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | berlevag
# Processing Record 9 of Set 1 | cheyenne
# Processing Record 10 of Set 1 | suntar
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 1 | northam
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | lavrentiya
# Processing Record 18 of Set 1 | caxito
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | port hedland
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | olafsvik
# Processing Record 25 of Set 1 | bouafle
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | nouadhibou
# Processing Record 29 of Set 1 | san quintin
# Processing Record 30 of Set 1 | kerouane
# Processing Record 31 of Set 1 | camana
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | ati
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | coquimbo
# Processing Record 37 of Set 1 | pokhara
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | turukhansk
# Processing Record 42 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | padang
# Processing Record 45 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 1 | suao
# City not found. Skipping...
# Processing Record 47 of Set 1 | nelson bay
# Processing Record 48 of Set 1 | iwanai
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | kshenskiy
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | lienz
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | makakilo city
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | san carlos del zulia
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | alberdi
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | marystown
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | mandalgovi
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | sao felix do xingu
# Processing Record 26 of Set 2 | north bend
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | preobrazheniye
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | ozinki
# Processing Record 36 of Set 2 | mapastepec
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | lata
# Processing Record 42 of Set 2 | itoman
# Processing Record 43 of Set 2 | agirish
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | saurimo
# Processing Record 47 of Set 2 | tarangnan
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | havre-saint-pierre
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | kaeo
# Processing Record 2 of Set 3 | adrar
# Processing Record 3 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | mulege
# Processing Record 6 of Set 3 | nortelandia
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | coxim
# Processing Record 9 of Set 3 | richards bay
# Processing Record 10 of Set 3 | mehamn
# Processing Record 11 of Set 3 | sibolga
# Processing Record 12 of Set 3 | erdenet
# Processing Record 13 of Set 3 | broken hill
# Processing Record 14 of Set 3 | torres
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | yar-sale
# Processing Record 18 of Set 3 | weihai
# Processing Record 19 of Set 3 | eureka
# Processing Record 20 of Set 3 | ancud
# Processing Record 21 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | vyazemskiy
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | fairbanks
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | gushikawa
# Processing Record 29 of Set 3 | husavik
# Processing Record 30 of Set 3 | bikin
# Processing Record 31 of Set 3 | priargunsk
# Processing Record 32 of Set 3 | mahanoro
# Processing Record 33 of Set 3 | mackenzie
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | hermanus
# Processing Record 36 of Set 3 | pangody
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 39 of Set 3 | rubiataba
# Processing Record 40 of Set 3 | kenai
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | felanitx
# Processing Record 43 of Set 3 | namatanai
# Processing Record 44 of Set 3 | zhanakorgan
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | ihosy
# Processing Record 47 of Set 3 | vestmannaeyjar
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | warri
# Processing Record 50 of Set 3 | viedma
# Processing Record 1 of Set 4 | dali
# Processing Record 2 of Set 4 | povenets
# Processing Record 3 of Set 4 | najran
# Processing Record 4 of Set 4 | malaruhatan
# Processing Record 5 of Set 4 | nushki
# Processing Record 6 of Set 4 | poronaysk
# Processing Record 7 of Set 4 | san lorenzo
# Processing Record 8 of Set 4 | hit
# Processing Record 9 of Set 4 | kashi
# Processing Record 10 of Set 4 | mecca
# Processing Record 11 of Set 4 | cockburn town
# Processing Record 12 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 4 | machico
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | altar
# Processing Record 17 of Set 4 | miramar
# Processing Record 18 of Set 4 | san miguelito
# Processing Record 19 of Set 4 | flinders
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | hay river
# Processing Record 23 of Set 4 | les cayes
# Processing Record 24 of Set 4 | sao joao da barra
# Processing Record 25 of Set 4 | panalingaan
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | bodrum
# Processing Record 29 of Set 4 | petric
# City not found. Skipping...
# Processing Record 30 of Set 4 | montana
# Processing Record 31 of Set 4 | raga
# Processing Record 32 of Set 4 | chekhov
# Processing Record 33 of Set 4 | karratha
# Processing Record 34 of Set 4 | nemuro
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | sao gabriel da cachoeira
# Processing Record 37 of Set 4 | panjakent
# Processing Record 38 of Set 4 | winnemucca
# Processing Record 39 of Set 4 | griffith
# Processing Record 40 of Set 4 | anadyr
# Processing Record 41 of Set 4 | maryanovka
# City not found. Skipping...
# Processing Record 42 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 4 | muroto
# Processing Record 44 of Set 4 | manthani
# Processing Record 45 of Set 4 | bom jesus da lapa
# Processing Record 46 of Set 4 | jiuquan
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | basco
# Processing Record 49 of Set 4 | aklavik
# Processing Record 50 of Set 4 | sola
# Processing Record 1 of Set 5 | prado
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | kikwit
# Processing Record 4 of Set 5 | kushmurun
# Processing Record 5 of Set 5 | mastic beach
# Processing Record 6 of Set 5 | ust-kuyga
# Processing Record 7 of Set 5 | itarema
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | ketchikan
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | tura
# Processing Record 12 of Set 5 | kastrakion
# Processing Record 13 of Set 5 | takoradi
# Processing Record 14 of Set 5 | mae hong son
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | zhezkazgan
# Processing Record 17 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 5 | elko
# Processing Record 19 of Set 5 | thomasville
# Processing Record 20 of Set 5 | bengkulu
# Processing Record 21 of Set 5 | deputatskiy
# Processing Record 22 of Set 5 | pacific grove
# Processing Record 23 of Set 5 | warwick
# Processing Record 24 of Set 5 | galle
# Processing Record 25 of Set 5 | trenggalek
# Processing Record 26 of Set 5 | acarau
# Processing Record 27 of Set 5 | ambulu
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | goya
# Processing Record 30 of Set 5 | maimon
# City not found. Skipping...
# Processing Record 31 of Set 5 | nikolskoye
# Processing Record 32 of Set 5 | turkistan
# Processing Record 33 of Set 5 | abha
# Processing Record 34 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 5 | keetmanshoop
# Processing Record 36 of Set 5 | deogarh
# Processing Record 37 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 5 | solnechnyy
# Processing Record 39 of Set 5 | saint anthony
# Processing Record 40 of Set 5 | tadine
# Processing Record 41 of Set 5 | batagay-alyta
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | kuytun
# Processing Record 44 of Set 5 | kongolo
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | akyab
# Processing Record 47 of Set 5 | bluff
# Processing Record 48 of Set 5 | lazaro cardenas
# Processing Record 49 of Set 5 | channagiri
# Processing Record 50 of Set 5 | shambu
# Processing Record 1 of Set 6 | coahuayana
# Processing Record 2 of Set 6 | vulturu
# Processing Record 3 of Set 6 | bahia honda
# Processing Record 4 of Set 6 | taonan
# Processing Record 5 of Set 6 | luwuk
# Processing Record 6 of Set 6 | khorixas
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | asau
# Processing Record 9 of Set 6 | longyearbyen
# Processing Record 10 of Set 6 | izhma
# Processing Record 11 of Set 6 | haines junction
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | muisne
# Processing Record 14 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 16 of Set 6 | buala
# Processing Record 17 of Set 6 | strezhevoy
# Processing Record 18 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | onega
# Processing Record 20 of Set 6 | la ronge
# Processing Record 21 of Set 6 | shakawe
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | nogales
# Processing Record 24 of Set 6 | tavda
# Processing Record 25 of Set 6 | shimoda
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | tazovskiy
# Processing Record 28 of Set 6 | tiznit
# Processing Record 29 of Set 6 | hambantota
# Processing Record 30 of Set 6 | ust-nera
# Processing Record 31 of Set 6 | san patricio
# Processing Record 32 of Set 6 | tchamba
# Processing Record 33 of Set 6 | chuy
# Processing Record 34 of Set 6 | ostersund
# Processing Record 35 of Set 6 | saint george
# Processing Record 36 of Set 6 | jutai
# Processing Record 37 of Set 6 | klaksvik
# Processing Record 38 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 6 | vaitape
# Processing Record 40 of Set 6 | chala
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | gat
# Processing Record 43 of Set 6 | karlshamn
# Processing Record 44 of Set 6 | shiraz
# Processing Record 45 of Set 6 | matara
# Processing Record 46 of Set 6 | ayan
# Processing Record 47 of Set 6 | panguna
# Processing Record 48 of Set 6 | lokosovo
# Processing Record 49 of Set 6 | atikokan
# Processing Record 50 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | isangel
# Processing Record 3 of Set 7 | port hardy
# Processing Record 4 of Set 7 | kaitangata
# Processing Record 5 of Set 7 | beloha
# Processing Record 6 of Set 7 | enshi
# Processing Record 7 of Set 7 | sapapalii
# City not found. Skipping...
# Processing Record 8 of Set 7 | khatanga
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | uyuni
# Processing Record 12 of Set 7 | umea
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 15 of Set 7 | bella union
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | benicarlo
# Processing Record 19 of Set 7 | broome
# Processing Record 20 of Set 7 | bolitoc
# Processing Record 21 of Set 7 | piacabucu
# Processing Record 22 of Set 7 | norman wells
# Processing Record 23 of Set 7 | altay
# Processing Record 24 of Set 7 | almaznyy
# Processing Record 25 of Set 7 | fernley
# Processing Record 26 of Set 7 | kloulklubed
# Processing Record 27 of Set 7 | kudahuvadhoo
# Processing Record 28 of Set 7 | qiongshan
# Processing Record 29 of Set 7 | natal
# Processing Record 30 of Set 7 | togur
# Processing Record 31 of Set 7 | odweyne
# Processing Record 32 of Set 7 | wilmington island
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | goteborg
# City not found. Skipping...
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | vanavara
# Processing Record 37 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 40 of Set 7 | gaoua
# Processing Record 41 of Set 7 | tarakan
# Processing Record 42 of Set 7 | peniche
# Processing Record 43 of Set 7 | san cristobal
# Processing Record 44 of Set 7 | westport
# Processing Record 45 of Set 7 | marsa matruh
# Processing Record 46 of Set 7 | caceres
# Processing Record 47 of Set 7 | zemio
# Processing Record 48 of Set 7 | cookeville
# Processing Record 49 of Set 7 | kulhudhuffushi
# Processing Record 50 of Set 7 | aksu
# Processing Record 1 of Set 8 | road town
# Processing Record 2 of Set 8 | cadillac
# Processing Record 3 of Set 8 | abonnema
# Processing Record 4 of Set 8 | sorland
# Processing Record 5 of Set 8 | luebo
# Processing Record 6 of Set 8 | malpe
# Processing Record 7 of Set 8 | kvarkeno
# Processing Record 8 of Set 8 | lebu
# Processing Record 9 of Set 8 | te anau
# Processing Record 10 of Set 8 | hanzhong
# Processing Record 11 of Set 8 | necochea
# Processing Record 12 of Set 8 | strabychovo
# Processing Record 13 of Set 8 | bozuyuk
# Processing Record 14 of Set 8 | salinas
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 8 | mahmudabad
# Processing Record 18 of Set 8 | zyryanka
# Processing Record 19 of Set 8 | yatou
# Processing Record 20 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | umuahia
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | marquette
# Processing Record 24 of Set 8 | aiken
# Processing Record 25 of Set 8 | ribeira grande
# Processing Record 26 of Set 8 | victor harbor
# Processing Record 27 of Set 8 | phalombe
# Processing Record 28 of Set 8 | tiksi
# Processing Record 29 of Set 8 | gizo
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | salalah
# Processing Record 32 of Set 8 | mangrol
# Processing Record 33 of Set 8 | houma
# Processing Record 34 of Set 8 | erenhot
# Processing Record 35 of Set 8 | karla
# Processing Record 36 of Set 8 | dhidhdhoo
# Processing Record 37 of Set 8 | kandrian
# Processing Record 38 of Set 8 | lucapa
# Processing Record 39 of Set 8 | santa maria
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | la orilla
# Processing Record 42 of Set 8 | solana beach
# Processing Record 43 of Set 8 | narrabri
# Processing Record 44 of Set 8 | tarancon
# Processing Record 45 of Set 8 | campobasso
# Processing Record 46 of Set 8 | dongkan
# Processing Record 47 of Set 8 | huarmey
# Processing Record 48 of Set 8 | mimongo
# Processing Record 49 of Set 8 | vardo
# Processing Record 50 of Set 8 | lugus
# Processing Record 1 of Set 9 | kuryk
# Processing Record 2 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 9 | kovdor
# Processing Record 4 of Set 9 | trat
# Processing Record 5 of Set 9 | lagos
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | bogorodskoye
# Processing Record 8 of Set 9 | cayenne
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | sinnamary
# Processing Record 11 of Set 9 | shenjiamen
# Processing Record 12 of Set 9 | phalaborwa
# Processing Record 13 of Set 9 | geraldton
# Processing Record 14 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 9 | katobu
# Processing Record 16 of Set 9 | saint-paul
# Processing Record 17 of Set 9 | drexel heights
# Processing Record 18 of Set 9 | sobrance
# Processing Record 19 of Set 9 | breytovo
# Processing Record 20 of Set 9 | tierra colorada
# Processing Record 21 of Set 9 | aitape
# Processing Record 22 of Set 9 | lasa
# Processing Record 23 of Set 9 | jonuta
# Processing Record 24 of Set 9 | garowe
# Processing Record 25 of Set 9 | santa cruz del norte
# Processing Record 26 of Set 9 | puerto escondido
# Processing Record 27 of Set 9 | polyarnyy
# Processing Record 28 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 9 | martapura
# Processing Record 30 of Set 9 | zheshart
# Processing Record 31 of Set 9 | hailar
# Processing Record 32 of Set 9 | stranda
# Processing Record 33 of Set 9 | karpathos
# Processing Record 34 of Set 9 | mackay
# Processing Record 35 of Set 9 | santa isabel
# Processing Record 36 of Set 9 | havelock
# Processing Record 37 of Set 9 | bambanglipuro
# Processing Record 38 of Set 9 | karasjok
# Processing Record 39 of Set 9 | tirano
# Processing Record 40 of Set 9 | itapirapua
# Processing Record 41 of Set 9 | madras
# Processing Record 42 of Set 9 | luderitz
# Processing Record 43 of Set 9 | itaituba
# Processing Record 44 of Set 9 | posse
# Processing Record 45 of Set 9 | joetsu
# Processing Record 46 of Set 9 | buraydah
# Processing Record 47 of Set 9 | puerto rico
# Processing Record 48 of Set 9 | zelenoborsk
# Processing Record 49 of Set 9 | maydolong
# Processing Record 50 of Set 9 | angra dos reis
# Processing Record 1 of Set 10 | grand gaube
# Processing Record 2 of Set 10 | verkhovazhye
# Processing Record 3 of Set 10 | dicabisagan
# Processing Record 4 of Set 10 | coatesville
# Processing Record 5 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 10 | kerewan
# Processing Record 7 of Set 10 | port blair
# Processing Record 8 of Set 10 | oussouye
# Processing Record 9 of Set 10 | shelby
# Processing Record 10 of Set 10 | humaita
# Processing Record 11 of Set 10 | great yarmouth
# Processing Record 12 of Set 10 | wajid
# Processing Record 13 of Set 10 | ternate
# Processing Record 14 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 10 | varberg
# Processing Record 16 of Set 10 | adre
# Processing Record 17 of Set 10 | kodinsk
# Processing Record 18 of Set 10 | port lincoln
# Processing Record 19 of Set 10 | talaya
# Processing Record 20 of Set 10 | constitucion
# Processing Record 21 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 10 | qaqortoq
# Processing Record 23 of Set 10 | kamaishi
# Processing Record 24 of Set 10 | kyabe
# Processing Record 25 of Set 10 | banposh
# Processing Record 26 of Set 10 | pevek
# Processing Record 27 of Set 10 | bathsheba
# Processing Record 28 of Set 10 | genhe
# Processing Record 29 of Set 10 | san policarpo
# Processing Record 30 of Set 10 | xique-xique
# Processing Record 31 of Set 10 | sirajganj
# Processing Record 32 of Set 10 | porto novo
# Processing Record 33 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 10 | mosquera
# Processing Record 35 of Set 10 | ventspils
# Processing Record 36 of Set 10 | sioux lookout
# Processing Record 37 of Set 10 | oistins
# Processing Record 38 of Set 10 | marawi
# Processing Record 39 of Set 10 | mocuba
# Processing Record 40 of Set 10 | houston
# Processing Record 41 of Set 10 | khani
# Processing Record 42 of Set 10 | erzin
# Processing Record 43 of Set 10 | evensk
# Processing Record 44 of Set 10 | yumen
# Processing Record 45 of Set 10 | buritis
# Processing Record 46 of Set 10 | grindavik
# Processing Record 47 of Set 10 | taoudenni
# Processing Record 48 of Set 10 | carutapera
# Processing Record 49 of Set 10 | san isidro
# Processing Record 50 of Set 10 | cacu
# Processing Record 1 of Set 11 | balabac
# Processing Record 2 of Set 11 | troitsko-pechorsk
# Processing Record 3 of Set 11 | otavi
# Processing Record 4 of Set 11 | portland
# Processing Record 5 of Set 11 | tilichiki
# Processing Record 6 of Set 11 | gamba
# Processing Record 7 of Set 11 | seminole
# Processing Record 8 of Set 11 | yarmouth
# Processing Record 9 of Set 11 | ambilobe
# Processing Record 10 of Set 11 | suez
# Processing Record 11 of Set 11 | save
# Processing Record 12 of Set 11 | champerico
# Processing Record 13 of Set 11 | stykkisholmur
# Processing Record 14 of Set 11 | camacha
# Processing Record 15 of Set 11 | kisangani
# Processing Record 16 of Set 11 | mbala
# Processing Record 17 of Set 11 | razdolinsk
# Processing Record 18 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 19 of Set 11 | morbegno
# Processing Record 20 of Set 11 | bowen
# Processing Record 21 of Set 11 | japura
# Processing Record 22 of Set 11 | nara
# Processing Record 23 of Set 11 | murgab
# Processing Record 24 of Set 11 | bonthe
# Processing Record 25 of Set 11 | panama
# Processing Record 26 of Set 11 | waingapu
# Processing Record 27 of Set 11 | inirida
# Processing Record 28 of Set 11 | sal rei
# Processing Record 29 of Set 11 | mao
# Processing Record 30 of Set 11 | hualmay
# Processing Record 31 of Set 11 | urumqi
# Processing Record 32 of Set 11 | nanortalik
# Processing Record 33 of Set 11 | neiafu
# Processing Record 34 of Set 11 | neuquen
# Processing Record 35 of Set 11 | apartado
# Processing Record 36 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 11 | bobon
# Processing Record 38 of Set 11 | bondo
# Processing Record 39 of Set 11 | kontagora
# Processing Record 40 of Set 11 | rantepao
# Processing Record 41 of Set 11 | havoysund
# Processing Record 42 of Set 11 | jedburgh
# Processing Record 43 of Set 11 | methoni
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | puksoozero
# Processing Record 46 of Set 11 | alekseyevsk
# Processing Record 47 of Set 11 | chicama
# Processing Record 48 of Set 11 | lenoir city
# Processing Record 49 of Set 11 | manzil salim
# Processing Record 50 of Set 11 | guanica
# Processing Record 1 of Set 12 | asbe teferi
# Processing Record 2 of Set 12 | ellsworth
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | atbasar
# Processing Record 5 of Set 12 | kattivakkam
# Processing Record 6 of Set 12 | comodoro rivadavia
# Processing Record 7 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 8 of Set 12 | siuna
# Processing Record 9 of Set 12 | thaba nchu
# Processing Record 10 of Set 12 | parintins
# Processing Record 11 of Set 12 | ishigaki
# Processing Record 12 of Set 12 | belgrade
# Processing Record 13 of Set 12 | ilulissat
# Processing Record 14 of Set 12 | rudnyy
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | corvallis
# Processing Record 17 of Set 12 | khilok
# Processing Record 18 of Set 12 | jundiai
# Processing Record 19 of Set 12 | bethanien
# Processing Record 20 of Set 12 | batemans bay
# Processing Record 21 of Set 12 | hovd
# Processing Record 22 of Set 12 | listvyanskiy
# Processing Record 23 of Set 12 | buta
# Processing Record 24 of Set 12 | sheltozero
# Processing Record 25 of Set 12 | seoul
# Processing Record 26 of Set 12 | yarada
# Processing Record 27 of Set 12 | dom pedrito
# Processing Record 28 of Set 12 | venice
# Processing Record 29 of Set 12 | kharp
# Processing Record 30 of Set 12 | luena
# Processing Record 31 of Set 12 | lincoln
# Processing Record 32 of Set 12 | roebourne
# Processing Record 33 of Set 12 | saint-louis
# Processing Record 34 of Set 12 | novonukutskiy
# Processing Record 35 of Set 12 | paamiut
# Processing Record 36 of Set 12 | fukue
# Processing Record 37 of Set 12 | prince rupert
# Processing Record 38 of Set 12 | ojinaga
# Processing Record 39 of Set 12 | pio xii
# Processing Record 40 of Set 12 | jiehu
# Processing Record 41 of Set 12 | norman
# Processing Record 42 of Set 12 | kargasok
# Processing Record 43 of Set 12 | aljezur
# Processing Record 44 of Set 12 | valparaiso
# Processing Record 45 of Set 12 | novopokrovka
# Processing Record 46 of Set 12 | muros
# Processing Record 47 of Set 12 | jiangkou
# Processing Record 48 of Set 12 | moerai
# Processing Record 49 of Set 12 | arica
# Processing Record 50 of Set 12 | honiara
# Processing Record 1 of Set 13 | krasnoselkup
# Processing Record 2 of Set 13 | tucumcari
# Processing Record 3 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 13 | reconquista
# Processing Record 5 of Set 13 | varese
# Processing Record 6 of Set 13 | marfino
# Processing Record 7 of Set 13 | khandbari
# Processing Record 8 of Set 13 | miri
# Processing Record 9 of Set 13 | illela
# Processing Record 10 of Set 13 | shingu
# Processing Record 11 of Set 13 | katherine
# Processing Record 12 of Set 13 | arinos
# Processing Record 13 of Set 13 | sabang
# Processing Record 14 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 15 of Set 13 | dalbandin
# Processing Record 16 of Set 13 | jacareacanga
# Processing Record 17 of Set 13 | trapani
# Processing Record 18 of Set 13 | black diamond
# Processing Record 19 of Set 13 | rorvik
# Processing Record 20 of Set 13 | celestun
# Processing Record 21 of Set 13 | mbigou
# Processing Record 22 of Set 13 | littleton
# Processing Record 23 of Set 13 | huangmei
# Processing Record 24 of Set 13 | nome
# Processing Record 25 of Set 13 | sayat
# Processing Record 26 of Set 13 | ambon
# Processing Record 27 of Set 13 | cinco esquinas
# Processing Record 28 of Set 13 | tocopilla
# Processing Record 29 of Set 13 | nabire
# Processing Record 30 of Set 13 | ingham
# Processing Record 31 of Set 13 | gonzales
# Processing Record 32 of Set 13 | cravo norte
# Processing Record 33 of Set 13 | namie
# Processing Record 34 of Set 13 | beaufort
# Processing Record 35 of Set 13 | arona
# Processing Record 36 of Set 13 | burica
# City not found. Skipping...
# Processing Record 37 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 38 of Set 13 | ridgecrest
# Processing Record 39 of Set 13 | bucerias
# Processing Record 40 of Set 13 | skjervoy
# Processing Record 41 of Set 13 | araxa
# Processing Record 42 of Set 13 | morondava
# Processing Record 43 of Set 13 | ambunti
# Processing Record 44 of Set 13 | port-gentil
# Processing Record 45 of Set 13 | coolum beach
# Processing Record 46 of Set 13 | tire
# Processing Record 47 of Set 13 | araguaina
# Processing Record 48 of Set 13 | ye
# City not found. Skipping...
# Processing Record 49 of Set 13 | abu samrah
# Processing Record 50 of Set 13 | panaba
# Processing Record 1 of Set 14 | sakaiminato
# Processing Record 2 of Set 14 | aksarka
# Processing Record 3 of Set 14 | santa marta de tormes
# Processing Record 4 of Set 14 | petatlan
# Processing Record 5 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 6 of Set 14 | lapua
# Processing Record 7 of Set 14 | sobolevo
# Processing Record 8 of Set 14 | aripuana
# Processing Record 9 of Set 14 | guerrero negro
# Processing Record 10 of Set 14 | sibanicu
# Processing Record 11 of Set 14 | rosario
# Processing Record 12 of Set 14 | tondela
# Processing Record 13 of Set 14 | maningrida
# Processing Record 14 of Set 14 | adwa
# Processing Record 15 of Set 14 | stornoway
# Processing Record 16 of Set 14 | vao
# Processing Record 17 of Set 14 | menzelinsk
# Processing Record 18 of Set 14 | przasnysz
# Processing Record 19 of Set 14 | kangaatsiaq
# Processing Record 20 of Set 14 | acapulco
# Processing Record 21 of Set 14 | shetpe
# Processing Record 22 of Set 14 | baddomalhi
# Processing Record 23 of Set 14 | gairo
# Processing Record 24 of Set 14 | margate
# Processing Record 25 of Set 14 | latehar
# Processing Record 26 of Set 14 | tabas
# Processing Record 27 of Set 14 | ishinomaki
# Processing Record 28 of Set 14 | great falls
# Processing Record 29 of Set 14 | gorom-gorom
# Processing Record 30 of Set 14 | innisfail
# Processing Record 31 of Set 14 | awbari
# Processing Record 32 of Set 14 | marzuq
# Processing Record 33 of Set 14 | cleburne
# Processing Record 34 of Set 14 | morant bay
# Processing Record 35 of Set 14 | zakupne
# Processing Record 36 of Set 14 | alexandria
# Processing Record 37 of Set 14 | ostrov
# Processing Record 38 of Set 14 | bol
# Processing Record 39 of Set 14 | verkhnyaya inta
# Processing Record 40 of Set 14 | lalmohan
# Processing Record 41 of Set 14 | zhigansk
# Processing Record 42 of Set 14 | ngorongoro
# Processing Record 43 of Set 14 | okhotsk
# Processing Record 44 of Set 14 | kailua
# Processing Record 45 of Set 14 | voh
# Processing Record 46 of Set 14 | navalcarnero
# Processing Record 47 of Set 14 | juazeiro
# Processing Record 48 of Set 14 | magomeni
# Processing Record 49 of Set 14 | isiolo
# Processing Record 50 of Set 14 | xilitla
# Processing Record 1 of Set 15 | betare oya
# Processing Record 2 of Set 15 | mayumba
# Processing Record 3 of Set 15 | ibra
# Processing Record 4 of Set 15 | dunedin
# Processing Record 5 of Set 15 | douentza
# Processing Record 6 of Set 15 | trinidad
# Processing Record 7 of Set 15 | blackwater
# Processing Record 8 of Set 15 | aksay
# Processing Record 9 of Set 15 | kirakira
# Processing Record 10 of Set 15 | grenfell
# Processing Record 11 of Set 15 | ekibastuz
# Processing Record 12 of Set 15 | sept-iles
# Processing Record 13 of Set 15 | hazorasp
# Processing Record 14 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 15 | maicao
# Processing Record 16 of Set 15 | kavieng
# Processing Record 17 of Set 15 | sabya
# Processing Record 18 of Set 15 | araouane
# Processing Record 19 of Set 15 | henties bay
# Processing Record 20 of Set 15 | malakal
# Processing Record 21 of Set 15 | vavatenina
# Processing Record 22 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 15 | oksfjord
# Processing Record 24 of Set 15 | kichmengskiy gorodok
# Processing Record 25 of Set 15 | wageningen
# Processing Record 26 of Set 15 | challapata
# Processing Record 27 of Set 15 | meulaboh
# Processing Record 28 of Set 15 | barentu
# Processing Record 29 of Set 15 | seydi
# Processing Record 30 of Set 15 | saint-ambroise
# Processing Record 31 of Set 15 | banepa
# Processing Record 32 of Set 15 | dovolnoye
# Processing Record 33 of Set 15 | allapalli
# Processing Record 34 of Set 15 | lingyuan
# Processing Record 35 of Set 15 | amuntai
# Processing Record 36 of Set 15 | evanston
# Processing Record 37 of Set 15 | drayton valley
# Processing Record 38 of Set 15 | itaquyry
# Processing Record 39 of Set 15 | rancho veloz
# Processing Record 40 of Set 15 | baykit
# Processing Record 41 of Set 15 | stanger
# Processing Record 42 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 15 | kirsanov
# Processing Record 46 of Set 15 | riverton
# Processing Record 47 of Set 15 | kautokeino
# Processing Record 48 of Set 15 | oranjemund
# Processing Record 49 of Set 15 | kawalu
# Processing Record 50 of Set 15 | roberval
# Processing Record 1 of Set 16 | port macquarie
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 695

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Vaini -21.2000 -175.2000     71.33        69         100       13.22
# 1      Quime -16.9833  -67.2167     52.02        90          80        2.95
# 2  Carnarvon -24.8667  113.6333     73.11        49           0       19.22
# 3    Palauig  15.4350  119.9045     84.70        68          96        5.84
# 4     Lompoc  34.6391 -120.4579     56.01        84           0       11.50
# 5    Mataura -46.1927  168.8643     51.48        97         100        3.53
# 6   Berlevag  70.8578   29.0864     33.80        80         100        5.75
# 7   Cheyenne  41.1400 -104.8203     38.77        86           0        0.00
# 8     Suntar  62.1444  117.6319     31.37        79         100        8.10
# 9  Jamestown  42.0970  -79.2353     62.19        83           0       13.80
#
#   Country Weather Description                 Date
# 0      TO          light rain  2022-10-26 04:12:33
# 1      BO       broken clouds  2022-10-26 04:12:34
# 2      AU           clear sky  2022-10-26 04:12:34
# 3      PH     overcast clouds  2022-10-26 04:12:35
# 4      US           clear sky  2022-10-26 04:12:36
# 5      NZ     overcast clouds  2022-10-26 04:12:37
# 6      NO     overcast clouds  2022-10-26 04:12:37
# 7      US           clear sky  2022-10-26 04:08:30
# 8      RU     overcast clouds  2022-10-26 04:12:12
# 9      US           clear sky  2022-10-26 04:12:39

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vaini      TO -21.2000 -175.2000     71.33        69         100
# 1      Quime      BO -16.9833  -67.2167     52.02        90          80
# 2  Carnarvon      AU -24.8667  113.6333     73.11        49           0
# 3    Palauig      PH  15.4350  119.9045     84.70        68          96
# 4     Lompoc      US  34.6391 -120.4579     56.01        84           0
# 5    Mataura      NZ -46.1927  168.8643     51.48        97         100
# 6   Berlevag      NO  70.8578   29.0864     33.80        80         100
# 7   Cheyenne      US  41.1400 -104.8203     38.77        86           0
# 8     Suntar      RU  62.1444  117.6319     31.37        79         100
# 9  Jamestown      US  42.0970  -79.2353     62.19        83           0
#
#    Wind Speed Weather Description
# 0       13.22          light rain
# 1        2.95       broken clouds
# 2       19.22           clear sky
# 3        5.84     overcast clouds
# 4       11.50           clear sky
# 5        3.53     overcast clouds
# 6        5.75     overcast clouds
# 7        0.00           clear sky
# 8        8.10     overcast clouds
# 9       13.80           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database2.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Out:
#   Input In [16]
#     open gmap
#          ^
# SyntaxError: invalid syntax
